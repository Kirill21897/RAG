# %%
from src.pipeline import RAGPipeline
import os
from dotenv import load_dotenv

load_dotenv()


rag = RAGPipeline(os.getenv("OPENAI_API_KEY"))
rag.ingest("data/raw/sample.pdf")
# Out:
# 2026-01-09 18:57:35,578 - INFO - Loading faiss with AVX512 support.
# 2026-01-09 18:57:35,579 - INFO - Could not load library with AVX512 support due to:
# ModuleNotFoundError("No module named 'faiss.swigfaiss_avx512'")
# 2026-01-09 18:57:35,580 - INFO - Loading faiss with AVX2 support.
# 2026-01-09 18:57:35,600 - INFO - Successfully loaded faiss with AVX2 support.
# 2026-01-09 18:57:39,038 - INFO - Use pytorch device_name: cpu
# 2026-01-09 18:57:39,039 - INFO - Load pretrained SentenceTransformer: all-MiniLM-L6-v2
# Loading embedding model: all-MiniLM-L6-v2
# 2026-01-09 18:57:42,358 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2026-01-09 18:57:42,385 - INFO - Going to convert document batch...
# 2026-01-09 18:57:42,385 - INFO - Initializing pipeline for StandardPdfPipeline with options hash e15bc6f248154cc62f8db15ef18a8ab7
# 2026-01-09 18:57:42,398 - INFO - Loading plugin 'docling_defaults'
# 2026-01-09 18:57:42,402 - INFO - Registered picture descriptions: ['vlm', 'api']
# 2026-01-09 18:57:42,414 - INFO - Loading plugin 'docling_defaults'
# 2026-01-09 18:57:42,420 - INFO - Registered ocr engines: ['auto', 'easyocr', 'ocrmac', 'rapidocr', 'tesserocr', 'tesseract']
# 2026-01-09 18:57:42,421 - INFO - rapidocr cannot be used because onnxruntime is not installed.
# 2026-01-09 18:57:42,422 - INFO - easyocr cannot be used because it is not installed.
# Loading document: data/raw/sample.pdf
# 2026-01-09 18:57:42,774 - INFO - Accelerator device: 'cpu'
# [INFO] 2026-01-09 18:57:42,790 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-09 18:57:42,800 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-09 18:57:42,818 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\user\Desktop\work\Technokaratos\Projects\RAG\.venv\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-09 18:57:42,819 [RapidOCR] main.py:50: Using C:\Users\user\Desktop\work\Technokaratos\Projects\RAG\.venv\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-09 18:57:42,996 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-09 18:57:42,997 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-09 18:57:42,999 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\user\Desktop\work\Technokaratos\Projects\RAG\.venv\Lib\site-packages\rapidocr\models\ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-09 18:57:43,000 [RapidOCR] main.py:50: Using C:\Users\user\Desktop\work\Technokaratos\Projects\RAG\.venv\Lib\site-packages\rapidocr\models\ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-09 18:57:43,078 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-09 18:57:43,079 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-09 18:57:43,106 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\user\Desktop\work\Technokaratos\Projects\RAG\.venv\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-09 18:57:43,107 [RapidOCR] main.py:50: Using C:\Users\user\Desktop\work\Technokaratos\Projects\RAG\.venv\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_rec_infer.pth
# 2026-01-09 18:57:43,333 - INFO - Auto OCR model selected rapidocr with torch.
# 2026-01-09 18:57:43,347 - INFO - Loading plugin 'docling_defaults'
# 2026-01-09 18:57:43,353 - INFO - Registered layout engines: ['docling_layout_default', 'docling_experimental_table_crops_layout']
# 2026-01-09 18:57:43,363 - INFO - Accelerator device: 'cpu'
# 2026-01-09 18:57:43,781 - INFO - Loading plugin 'docling_defaults'
# 2026-01-09 18:57:43,783 - INFO - Registered table structure engines: ['docling_tableformer']
# 2026-01-09 18:57:43,988 - INFO - Accelerator device: 'cpu'
# 2026-01-09 18:57:44,299 - INFO - Processing document sample.pdf
# 2026-01-09 18:57:49,115 - INFO - Finished converting document sample.pdf in 6.75 sec.
# 2026-01-09 18:57:49,150 - WARNING - Parameter `strict_text` has been deprecated and will be ignored.
# 2026-01-09 18:57:49,162 - WARNING - Parameter `strict_text` has been deprecated and will be ignored.
# Saved intermediate file: data/raw_converted.txt
# Total characters: 6872
# Created 16 chunks.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Index built successfully.

# %%
answer = rag.query("Что такое регенеративное сельское хозяйство")
print(answer)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-01-09 18:57:55,460 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Регенеративное сельское хозяйство - это система практик, направленная не только на минимизацию вреда, но и на восстановление экосистемных функций, таких как плодородие почв, биоразнообразие, водный баланс и углеродное поглощение. Ключевые принципы регенеративного земледелия включают minimизацию механической обработки почвы, поддержание постоянного почвенного покрова с использованием покровных культур, ротацию культур и интеграцию различных сельскохозяйственных практик.
