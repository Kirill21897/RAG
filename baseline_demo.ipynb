# %%
from src.pipeline import RAGPipeline
import os
from dotenv import load_dotenv

load_dotenv()


rag = RAGPipeline(os.getenv("OPENAI_API_KEY"))
rag.ingest("data/raw/sample.pdf")
'''
answer = rag.query("What is the main topic of this document?")
print(answer)
'''
# Out:
# 2026-01-08 13:55:55,322 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2026-01-08 13:55:55,353 - INFO - Going to convert document batch...
# 2026-01-08 13:55:55,354 - INFO - Initializing pipeline for StandardPdfPipeline with options hash e15bc6f248154cc62f8db15ef18a8ab7
# 2026-01-08 13:55:55,370 - INFO - Loading plugin 'docling_defaults'
# 2026-01-08 13:55:55,379 - INFO - Registered picture descriptions: ['vlm', 'api']
# 2026-01-08 13:55:55,390 - INFO - Loading plugin 'docling_defaults'
# 2026-01-08 13:55:55,416 - INFO - Registered ocr engines: ['auto', 'easyocr', 'ocrmac', 'rapidocr', 'tesserocr', 'tesseract']
# 2026-01-08 13:55:55,468 - INFO - rapidocr cannot be used because onnxruntime is not installed.
# 2026-01-08 13:55:55,470 - INFO - easyocr cannot be used because it is not installed.
# 2026-01-08 13:55:55,981 - INFO - Accelerator device: 'cpu'
# [INFO] 2026-01-08 13:55:55,996 [RapidOCR] base.py:22: Using engine_name: torch
# ...
